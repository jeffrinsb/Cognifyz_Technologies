# %%
#Level 4: Task 9:  Expectations from Investments
#Objective: Summarize participants’ expectations from investments

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
expectation_counts = df['Expect'].value_counts()

# %%
print("Top Expectations from Investments:\n", expectation_counts.head(10))
# Out:
# Top Expectations from Investments:
#  Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64

# %%
print("\nSummary: Participants expect investments to provide", ', '.join(expectation_counts.index[:5]))
# Out:
# Summary: Participants expect investments to provide 20%-30%, 30%-40%, 10%-20%
