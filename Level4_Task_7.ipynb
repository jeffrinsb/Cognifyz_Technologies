# %%
#Level 4: Task 7: Common Information Sources
#Objective: Analyze common sources participants rely on for investment information.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
source_counts = df['Source'].value_counts()

# %%
print("Most Common Information Sources:\n", source_counts.head(10))
# Out:
# Most Common Information Sources:
#  Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %%
print("\nSummary: The most relied-on sources for investment information are", ', '.join(source_counts.index[:5]))
# Out:
# Summary: The most relied-on sources for investment information are Financial Consultants, Newspapers and Magazines, Television, Internet
