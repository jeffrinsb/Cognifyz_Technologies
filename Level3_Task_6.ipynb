# %%
#Level 3: Task 6: Savings Objectives
#Objective: Identify and present main savings objectives.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
savings_counts = df['What are your savings objectives?'].value_counts()

# %%
print("Savings Objectives:\n", savings_counts)
# Out:
# Savings Objectives:
#  What are your savings objectives?
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: count, dtype: int64

# %%
for objective, count in savings_counts.items():
    print(f"- {objective}: {count} people mentioned this as their savings goal.")
# Out:
# - Retirement Plan: 24 people mentioned this as their savings goal.
# - Health Care: 13 people mentioned this as their savings goal.
# - Education: 3 people mentioned this as their savings goal.
