# %%
#Level 1: Task 2: Descriptive Statistics
#Objective: Present basic statistics for numerical columns.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')

# %%
 #Identify numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns
print("Numerical Columns:", numerical_columns)
# Out:
# Numerical Columns: Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %%
#Calculate descriptive statistics
stats = df[numerical_columns].describe().T
stats['median'] = df[numerical_columns].median()
print(stats[['mean', 'median', 'std', 'min', 'max']])
# Out:
#                     mean  median       std   min   max
# age               27.800    27.0  3.560467  21.0  35.0
# Mutual_Funds       2.550     2.0  1.197219   1.0   7.0
# Equity_Market      3.475     4.0  1.131994   1.0   6.0
# Debentures         5.750     6.5  1.675617   1.0   7.0
# Government_Bonds   4.650     5.0  1.369072   1.0   7.0
# Fixed_Deposits     3.575     3.5  1.795828   1.0   7.0
# PPF                2.025     1.0  1.609069   1.0   6.0
# Gold               5.975     6.0  1.143263   2.0   7.0
